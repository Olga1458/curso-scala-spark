// %%
scala.util.Properties.versionString
// Out:
// res2: String = "version 3.8.1"

// %%
scala.util.Properties.versionString
// Out:
// res1: String = "version 2.13.18"

// %%
val idsConDuplicados = List ( "U-101", "U-205", "U-101", "U-308", "U-205",
"U-412", "U-101", "U-308", "U-519", "U-205")
// Out:
// idsConDuplicados: List[String] = List(
//   "U-101",
//   "U-205",
//   "U-101",
//   "U-308",
//   "U-205",
//   "U-412",
//   "U-101",
//   "U-308",
//   "U-519",
//   "U-205"
// )

// %%
val idsUnicos = idsConDuplicados.toSet
// Out:
// idsUnicos: Set[String] = HashSet("U-205", "U-308", "U-519", "U-412", "U-101")
